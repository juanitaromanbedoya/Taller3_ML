# %%
#pip install openpyxl

import pandas as pd 

df = pd.read_excel('dataset_ventas.xlsx', engine='openpyxl')
df.head()
# Out:
#   fecha,ciudad,categoria,producto,cantidad,precio_unitario,total_venta
# 0  2025-11-24,MedellÃ­n,TecnologÃ­a,Monitor,8,605...
# 1  2025-03-13,MedellÃ­n,PapelerÃ­a,Cuaderno,19,11...
# 2  2025-01-17,MedellÃ­n,TecnologÃ­a,Teclado,8,134...
# 3  2025-11-05,MedellÃ­n,PapelerÃ­a,Lapicero,18,11...
# 4  2025-04-23,Barranquilla,PapelerÃ­a,Marcador,1,...
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.
